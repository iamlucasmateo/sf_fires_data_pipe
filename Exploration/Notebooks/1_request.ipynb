# %%
import requests
from config import api_config

# %%
APP_TOKEN = api_config["app_token"]
SECRET_TOKEN = api_config["secret_token"]
DATASET_ID = "wr8u-xric"
DATA_URL = f"https://data.sfgov.org/resource/{DATASET_ID}.json"
COUNT_QUERY = "?$select=count(ID)"

headers = {
  "X-App-Token": APP_TOKEN, # config.app_token
  "Content-Type": "application/json"
}

# %%
req_count = requests.get(
    f"{DATA_URL}{COUNT_QUERY}",
    headers=headers
)
total_rows = req_count.json()[0]["count_ID"]

LIMIT_QUERY = f"?$limit={total_rows}"

req = requests.get(
    f"{DATA_URL}{LIMIT_QUERY}",
    headers=headers
)
data = req.json()

# %%
data.__sizeof__()
# Out:
# 4826288

# %%
import pandas as pd

# %%
import pickle

with open('col_data_types.pickle', 'rb') as handle:
    columns = pickle.load(handle)

# %%
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#   incident_number exposure_number         id        address  \
# 0         8028304               0  080283040  150 Elsie St.
# 1         8028303               0  080283030  85 Turner Tr.
# 2         8028309               0  080283090    175 6th St.
#
#          incident_date call_number           alarm_dttm         arrival_dttm  \
# 0  2008-04-01T00:00:00   080920257  2008-04-01T18:06:37  2008-04-01T18:15:19
# 1  2008-04-01T00:00:00   080920256  2008-04-01T18:00:52  2008-04-01T18:06:30
# 2  2008-04-01T00:00:00   080920262  2008-04-01T18:42:06  2008-04-01T18:45:23
#
#             close_dttm city  ... detector_type detector_operation  \
# 0  2008-04-01T18:21:48   SF  ...           NaN                NaN
# 1  2008-04-01T18:22:18   SF  ...           NaN                NaN
# 2  2008-04-01T18:53:25   SF  ...           NaN                NaN
#
#   detector_effectiveness detector_failure_reason  \
# 0                    NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573968 entries, 0 to 573967
# Data columns (total 64 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   incident_number                               573968 non-null  object
#  1   exposure_number                               573968 non-null  object
#  2   id                                            573968 non-null  object
#  3   address                                       573664 non-null  object
#  4   incident_date                                 573968 non-null  object
#  5   call_number                                   573968 non-null  object
#  6   alarm_dttm                                    573968 non-null  object
#  7   arrival_dttm                                  573922 non-null  object
#  8   close_dttm                                    573965 non-null  object
# ...

# %%
DATASET_ID = "wr8u-xric"
METADATA_QUERY = f"?ids={DATASET_ID}"
METADATA_URL = f"http://api.us.socrata.com/api/catalog/v1"

# %%
metadata_req = requests.get(
    f"{METADATA_URL}{METADATA_QUERY}",
    headers=headers
)

metadata = metadata_req.json()

# %%
resource_metadata = metadata["results"][0]["resource"]
resource_metadata["columns_name"]
# Out:
# ['First Unit On Scene',
#  'Arrival DtTm',
#  'Detector Failure Reason',
#  'Fire Spread',
#  'Automatic Extinguishing Sytem Type',
#  'Structure Type',
#  'Number of floors with minimum damage',
#  'Supervisor District',
#  'Detector Type',
#  'Item First Ignited',
#  'Number of floors with significant damage',
#  'ID',
#  'Estimated Contents Loss',
#  'Action Taken Other',
#  'Human Factors Associated with Ignition',
#  'Number of Sprinkler Heads Operating',
#  'Automatic Extinguishing System Present',
#  'Civilian Fatalities',
#  'Mutual Aid',
#  'Floor of Fire Origin',
#  'Fire Fatalities',
#  'point',
#  'Incident Number',
#  'Address',
#  'Call Number',
#  'Ignition Factor Secondary',
#  'Alarm DtTm',
#  'Automatic Extinguishing Sytem Failure Reason',
#  'Detector Operation',
#  'Civilian Injuries',
#  'Number of Alarms',
#  'Action Taken Primary',
#  'Suppression Units',
#  'Number of floors with extreme damage',
#  'Automatic Extinguishing Sytem Perfomance',
#  'City',
# ...

# %%
resource_metadata["columns_datatype"]
# Out:
# ['Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Number',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Number',
#  'Text',
#  'Number',
#  'Number',
#  'Point',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Number',
#  'Text',
#  'Number',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Number',
#  'Text',
#  'Number',
#  'Text',
#  'Text',
#  'Number',
#  'Number',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Text',
#  'Number']
